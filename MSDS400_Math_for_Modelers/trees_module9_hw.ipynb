# %% [markdown]
# 🌳 RGB-to-Sentiment Decision Tree Explorer
# This tool helps analyze how RGB color values (used in metaphorical color assignments) relate to semantic sentiment scores in the La Matriz dataset. Using a Decision Tree Regressor, we explore how specific thresholds in Red (R), Green (G), and Blue (B) channels split the data to predict sentiment intensity.
#
# 🧠 What This Does
# Input: RGB values from 216 known color points labeled by their closest human-readable color.
#
# Output: A machine-learned tree model that approximates the sentiment score based on RGB values.
#
# Interactive Exploration:
#
# Choose a color from the dropdown.
#
# View all entries for that color, comparing actual sentiment vs tree-predicted values.
#
# Visualize the entire trained decision tree.
#
# 📐 Mathematical Concepts
# Decision Trees:
#
# The algorithm partitions the RGB color space into axis-aligned regions.
#
# Each split minimizes the mean squared error between predicted and actual sentiment scores.
#
# Nodes are split on thresholds like R <= 175 or G <= 125 that most reduce overall variance in sentiment.
#
# Model Input:
#
# 𝑋
# =
# [[’R’, ’G’, ’B’]]
# (Numerical RGB data)
# X=[[’R’, ’G’, ’B’]](Numerical RGB data)
# 𝑦
# =
# Sentiment Score
# (Real-valued target)
# y=Sentiment Score(Real-valued target)
# 🔍 Use Cases
# Visual pattern discovery: Identify which color channels most affect semantic sentiment.
#
# Client analysis: Check whether metaphor colors assigned to clients tend to carry higher or lower sentiment loads.
#
# Data refinement: Detect inconsistencies or outliers in RGB labeling vs intended emotional weight.

# %%
# !pip install ipywidgets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 15.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor, plot_tree
from ipywidgets import interact, Dropdown, Output, VBox, HBox, Button, Label
from IPython.display import display

# Load data
semantic_df = pd.read_csv("semantic_rgb_mapping_with_sentiment.csv")

# Preprocess
semantic_df.dropna(subset=['Sentiment Score'], inplace=True)
semantic_df['Color'] = semantic_df['Closest Color'].str.lower()

# Setup decision tree
X = semantic_df[['R', 'G', 'B']]
y = semantic_df['Sentiment Score']
tree = DecisionTreeRegressor(max_depth=3)
tree.fit(X, y)

# Visualization Output
output = Output()

# Dropdown for color selection
color_dropdown = Dropdown(
    options=sorted(semantic_df['Color'].unique()),
    description='Color:',
    layout={'width': '300px'}
)

# Function to analyze color with tree prediction
@output.capture()
def on_color_selected(color):
    color_data = semantic_df[semantic_df['Color'] == color]
    if color_data.empty:
        print(f"❌ No data found for color: {color}")
        return

    print(f"\n🎨 Analyzing color: {color.title()}")
    for _, row in color_data.iterrows():
        r, g, b = row['R'], row['G'], row['B']
        predicted = tree.predict([[r, g, b]])[0]
        print(f"  RGB({int(r)}, {int(g)}, {int(b)}) → Predicted Sentiment: {predicted:.3f} | Actual: {row['Sentiment Score']:.3f}")

    # Plot the decision tree
    fig, ax = plt.subplots(figsize=(12, 6))
    plot_tree(tree, feature_names=['R', 'G', 'B'], filled=True, ax=ax)
    plt.title("Decision Tree - RGB to Sentiment")
    plt.show()

interact(on_color_selected, color=color_dropdown)
display(output)
# Out:
# interactive(children=(Dropdown(description='Color:', layout=Layout(width='300px'), options=('black', 'blue', '…
# Output()

# %%
# !pip install docx
from docx import Document
from docx.shared import Pt
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT

# Load the full text content from user
full_text = """
COLOR SEQUENCES
================================================================================
SUMMARY FOR 'KNOT' PATHWAY
================================================================================
# Analysis of the 'knot' Color Pathway

## Overview

The 'knot' pathway consists of 8 colors: white, blue, green, red, black, brown, yellow, purple. Overall, this pathway exhibits a positive progression (improving sentiment) with an average sentiment of 0.45 (positive).

## Individual Color Analysis

... (Text truncated for brevity; the full version would include all pathway summaries as provided by the user)
"""

# Create a new Word document
doc = Document()
doc.add_heading("Color Visualization Guide", 0)

# Add the full text, split by paragraphs
for line in full_text.splitlines():
    if line.strip() == "":
        continue  # skip empty lines
    para = doc.add_paragraph(line.strip())
    para.style.font.size = Pt(11)
    para.alignment = WD_PARAGRAPH_ALIGNMENT.LEFT

# Save the document
file_path = "/mnt/data/Color_Visualization_Guide_Full.docx"
doc.save(file_path)

file_path
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for docx: filename=docx-0.2.4-py3-none-any.whl size=53893 sha256=c583f8224e6e929a7ec22b538f73271323a9e6dea3382fd8860c91b2bdfb59ec
#   Stored in directory: /root/.cache/pip/wheels/c1/3e/c3/e81c11effd0be5658a035947c66792dd993bcff317eae0e1ed
# Successfully built docx
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-6d0e20a2982a> in <cell line: 0>()
#       1 get_ipython().system('pip install docx')
# ----> 2 from docx import Document
#       3 from docx.shared import Pt
#       4 from docx.enum.text import WD_PARAGRAPH_ALIGNMENT
#       5
#
# /usr/local/lib/python3.11/dist-packages/docx.py in <module>
#      28     TAGS = {}
#      29
# ---> 30 from exceptions import PendingDeprecationWarning
# ...
